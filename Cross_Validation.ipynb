# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabari2002/Machine-Learning----Intermediate/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
data = pd.read_csv("/content/gdrive/My Drive/Sample data/melbourne_data.csv")
df = pd.DataFrame(data)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df.shape
# Out:
# (13580, 21)

# %%
cols_to_use = ['Rooms', 'Distance', 'Landsize', 'BuildingArea', 'YearBuilt']
X = data[cols_to_use]

y = data.Price  #target

# %% [markdown]
# Then, we define a pipeline that uses an imputer to fill in missing values and a random forest model to make predictions

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

my_pipeline = Pipeline(steps=[('preprocessor', SimpleImputer()),('model', RandomForestRegressor(n_estimators=100, random_state=0))])

# %%
from sklearn.model_selection import cross_val_score

# multiplying by -1 because sklearn return value in negative
scores = -1 * cross_val_score(my_pipeline, X, y,
                              cv=5,
                              scoring='neg_mean_absolute_error')

print("MAE scores:\n", scores)
# Out:
# MAE scores:
#  [301030.37999702 301815.50787799 285449.9265583  234645.50725674
#  259420.38429285]

# %%
print("Average MAE score (across experiments):")
print(scores.mean())
# Out:
# Average MAE score (across experiments):
# 276472.34119658044

# %% [markdown]
# **Conclusion**
#
# Using cross-validation yields a much better measure of model quality, with the added benefit of cleaning up our code: note that we no longer need to keep track of separate training and validation sets. So, especially for small datasets, it's a good improvement!
